# %%
import pandas as pd

# %% [markdown]
# ## _**DATA LOAD**_

# %%
df = pd.read_csv("pf.csv")
df
# Out:
#         top   left       date      qtr time_remaining result  shot_type  \
# 0     310.0  203.0  18-Oct-22  1st Qtr           9:26  False        3.0
# 1       NaN  259.0  18-Oct-22  1st Qtr           8:38  False        2.0
# 2     143.0    NaN  18-Oct-22  1st Qtr           8:10  False        2.0
# 3      68.0  215.0  18-Oct-22  1st Qtr            NaN    NaN        2.0
# 4      66.0  470.0  18-Oct-22  1st Qtr           1:02  False        NaN
# ...     ...    ...        ...      ...            ...    ...        ...
# 1528  118.0  274.0  22-May-23  4th Qtr           6:49  False        2.0
# 1529  109.0  221.0  22-May-23  4th Qtr           5:03  False        2.0
# 1530   78.0  254.0  22-May-23  4th Qtr           3:20    NaN        2.0
# 1531   78.0   46.0  22-May-23  4th Qtr           0:26  False        2.0
# 1532   58.0    NaN  22-May-23  4th Qtr           0:01  False        NaN
#
#       distance_ft   lead  lebron_team_score  opponent_team_score opponent  \
# ...

# %%
df.shape
# Out:
# (1533, 15)

# %%
df.head()
# Out:
#      top   left       date      qtr time_remaining result  shot_type  \
# 0  310.0  203.0  18-Oct-22  1st Qtr           9:26  False        3.0
# 1    NaN  259.0  18-Oct-22  1st Qtr           8:38  False        2.0
# 2  143.0    NaN  18-Oct-22  1st Qtr           8:10  False        2.0
# 3   68.0  215.0  18-Oct-22  1st Qtr            NaN    NaN        2.0
# 4   66.0  470.0  18-Oct-22  1st Qtr           1:02  False        NaN
#
#    distance_ft   lead  lebron_team_score  opponent_team_score opponent team  \
# 0         26.0    NaN                2.0                  2.0      GSW  LAL
# 1         16.0  False                NaN                  5.0      GSW  LAL
# 2         11.0  False                4.0                  7.0      GSW  LAL
# 3          3.0    NaN               12.0                 19.0      GSW  LAL
# 4          NaN  False               22.0                  NaN      GSW  LAL
#
#    season  color
# 0  2023.0    red
# 1  2023.0    red
# 2  2023.0    red
# 3  2023.0  green
# ...

# %%
df.tail()
# Out:
#         top   left       date      qtr time_remaining result  shot_type  \
# 1528  118.0  274.0  22-May-23  4th Qtr           6:49  False        2.0
# 1529  109.0  221.0  22-May-23  4th Qtr           5:03  False        2.0
# 1530   78.0  254.0  22-May-23  4th Qtr           3:20    NaN        2.0
# 1531   78.0   46.0  22-May-23  4th Qtr           0:26  False        2.0
# 1532   58.0    NaN  22-May-23  4th Qtr           0:01  False        NaN
#
#       distance_ft   lead  lebron_team_score  opponent_team_score opponent  \
# 1528          8.0  False               98.0                102.0      DEN
# 1529          6.0  False              100.0                102.0      DEN
# 1530          3.0  False              104.0                107.0      DEN
# 1531          NaN  False              111.0                113.0      DEN
# 1532          5.0  False                NaN                113.0      DEN
#
#      team  season  color
# 1528  NaN  2023.0    NaN
# 1529  NaN  2023.0    red
# ...

# %%
df.sample(3)
# Out:
#         top   left       date      qtr time_remaining result  shot_type  \
# 1387  214.0  152.0   6-May-23  2nd Qtr           8:02  False        2.0
# 689    56.0  263.0        NaN  4th Qtr           0:48   True        2.0
# 918   256.0  101.0  31-Jan-23  1st Qtr           7:13  False        3.0
#
#       distance_ft   lead  lebron_team_score  opponent_team_score opponent  \
# 1387         19.0  False               29.0                 37.0      GSW
# 689           2.0  False              132.0                132.0      SAC
# 918          25.0   True               10.0                  5.0      NYK
#
#      team  season  color
# 1387  LAL  2023.0    red
# 689   LAL  2023.0  green
# 918   LAL  2023.0    red

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1533 entries, 0 to 1532
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   top                  1444 non-null   float64
#  1   left                 1419 non-null   float64
#  2   date                 1438 non-null   object
#  3   qtr                  1434 non-null   object
#  4   time_remaining       1441 non-null   object
#  5   result               1433 non-null   object
#  6   shot_type            1424 non-null   float64
#  7   distance_ft          1419 non-null   float64
#  8   lead                 1431 non-null   object
#  9   lebron_team_score    1416 non-null   float64
#  10  opponent_team_score  1433 non-null   float64
#  11  opponent             1426 non-null   object
#  12  team                 1422 non-null   object
#  13  season               1417 non-null   float64
#  14  color                1437 non-null   object
# ...

# %%
df.describe()
# Out:
#                top         left    shot_type  distance_ft  lebron_team_score  \
# count  1444.000000  1419.000000  1424.000000  1419.000000        1416.000000
# mean    150.863573   231.199436     2.315309    13.021142          60.052966
# std      98.477355    91.754965     0.464802    10.715627          35.271296
# min       0.000000     0.000000     2.000000     0.000000           0.000000
# 25%      67.000000   192.000000     2.000000     3.000000          32.000000
# 50%      98.000000   238.000000     2.000000    10.000000          60.500000
# 75%     250.000000   261.000000     3.000000    25.000000          89.000000
# max     389.000000   478.000000     3.000000    34.000000         140.000000
#
#        opponent_team_score  season
# count          1433.000000  1417.0
# mean             58.841591  2023.0
# std              35.501486     0.0
# min               0.000000  2023.0
# 25%              31.000000  2023.0
# 50%              59.000000  2023.0
# ...

# %%
df.describe(include="all")
# Out:
#                 top         left       date      qtr time_remaining result  \
# count   1444.000000  1419.000000       1438     1434           1441   1433
# unique          NaN          NaN         72        6            602      2
# top             NaN          NaN  24-Jan-23  2nd Qtr           0:00   True
# freq            NaN          NaN         28      382             13    719
# mean     150.863573   231.199436        NaN      NaN            NaN    NaN
# std       98.477355    91.754965        NaN      NaN            NaN    NaN
# min        0.000000     0.000000        NaN      NaN            NaN    NaN
# 25%       67.000000   192.000000        NaN      NaN            NaN    NaN
# 50%       98.000000   238.000000        NaN      NaN            NaN    NaN
# 75%      250.000000   261.000000        NaN      NaN            NaN    NaN
# max      389.000000   478.000000        NaN      NaN            NaN    NaN
#
#           shot_type  distance_ft  lead  lebron_team_score  \
# ...

# %% [markdown]
# ## _**DATA CLEANING**_

# %%
df.isnull()
# Out:
#         top   left   date    qtr  time_remaining  result  shot_type  \
# 0     False  False  False  False           False   False      False
# 1      True  False  False  False           False   False      False
# 2     False   True  False  False           False   False      False
# 3     False  False  False  False            True    True      False
# 4     False  False  False  False           False   False       True
# ...     ...    ...    ...    ...             ...     ...        ...
# 1528  False  False  False  False           False   False      False
# 1529  False  False  False  False           False   False      False
# 1530  False  False  False  False           False    True      False
# 1531  False  False  False  False           False   False      False
# 1532  False   True  False  False           False   False       True
#
#       distance_ft   lead  lebron_team_score  opponent_team_score  opponent  \
# ...

# %%
df.isnull().sum()
# Out:
# top                     89
# left                   114
# date                    95
# qtr                     99
# time_remaining          92
# result                 100
# shot_type              109
# distance_ft            114
# lead                   102
# lebron_team_score      117
# opponent_team_score    100
# opponent               107
# team                   111
# season                 116
# color                   96
# dtype: int64

# %%
df.columns
# Out:
# Index(['top', 'left', 'date', 'qtr', 'time_remaining', 'result', 'shot_type',
#        'distance_ft', 'lead', 'lebron_team_score', 'opponent_team_score',
#        'opponent', 'team', 'season', 'color'],
#       dtype='object')

# %%
df.rename(columns={"time_remaining":"time", "shot_type":"shot", "distance_ft":"distance","lebron_team_score":"lbscore", "opponent_team_score":"opscore"},inplace=True)
df
# Out:
#         top   left       date      qtr  time result  shot  distance   lead  \
# 0     310.0  203.0  18-Oct-22  1st Qtr  9:26  False   3.0      26.0    NaN
# 1       NaN  259.0  18-Oct-22  1st Qtr  8:38  False   2.0      16.0  False
# 2     143.0    NaN  18-Oct-22  1st Qtr  8:10  False   2.0      11.0  False
# 3      68.0  215.0  18-Oct-22  1st Qtr   NaN    NaN   2.0       3.0    NaN
# 4      66.0  470.0  18-Oct-22  1st Qtr  1:02  False   NaN       NaN  False
# ...     ...    ...        ...      ...   ...    ...   ...       ...    ...
# 1528  118.0  274.0  22-May-23  4th Qtr  6:49  False   2.0       8.0  False
# 1529  109.0  221.0  22-May-23  4th Qtr  5:03  False   2.0       6.0  False
# 1530   78.0  254.0  22-May-23  4th Qtr  3:20    NaN   2.0       3.0  False
# 1531   78.0   46.0  22-May-23  4th Qtr  0:26  False   2.0       NaN  False
# 1532   58.0    NaN  22-May-23  4th Qtr  0:01  False   NaN       5.0  False
#
#       lbscore  opscore opponent team  season  color
# ...

# %%
df.dropna()
# Out:
#         top   left       date      qtr   time result  shot  distance   lead  \
# 6     230.0   54.0  18-Oct-22  2nd Qtr  10:30  False   3.0      26.0  False
# 9     273.0    0.0  18-Oct-22  2nd Qtr   8:55  False   3.0      25.0  False
# 10     62.0  224.0  18-Oct-22  2nd Qtr   7:06  False   2.0       2.0  False
# 14     53.0  240.0  18-Oct-22  2nd Qtr   0:58  False   2.0       0.0  False
# 15    230.0   71.0  18-Oct-22  3rd Qtr  10:49   True   3.0      25.0  False
# ...     ...    ...        ...      ...    ...    ...   ...       ...    ...
# 1507  306.0  280.0  20-May-23  4th Qtr   1:27  False   3.0      26.0  False
# 1517   72.0  238.0  22-May-23  2nd Qtr   9:17   True   2.0       2.0   True
# 1519   50.0  240.0  22-May-23  2nd Qtr   5:18   True   2.0       0.0   True
# 1520   87.0  257.0  22-May-23  2nd Qtr   4:08   True   2.0       4.0   True
# 1521  262.0   85.0  22-May-23  3rd Qtr   5:27  False   3.0      26.0   True
#
#       lbscore  opscore opponent team  season  color
# ...

# %%
df.fillna(804)
# Out:
#         top   left       date      qtr  time result   shot  distance   lead  \
# 0     310.0  203.0  18-Oct-22  1st Qtr  9:26  False    3.0      26.0    804
# 1     804.0  259.0  18-Oct-22  1st Qtr  8:38  False    2.0      16.0  False
# 2     143.0  804.0  18-Oct-22  1st Qtr  8:10  False    2.0      11.0  False
# 3      68.0  215.0  18-Oct-22  1st Qtr   804    804    2.0       3.0    804
# 4      66.0  470.0  18-Oct-22  1st Qtr  1:02  False  804.0     804.0  False
# ...     ...    ...        ...      ...   ...    ...    ...       ...    ...
# 1528  118.0  274.0  22-May-23  4th Qtr  6:49  False    2.0       8.0  False
# 1529  109.0  221.0  22-May-23  4th Qtr  5:03  False    2.0       6.0  False
# 1530   78.0  254.0  22-May-23  4th Qtr  3:20    804    2.0       3.0  False
# 1531   78.0   46.0  22-May-23  4th Qtr  0:26  False    2.0     804.0  False
# 1532   58.0  804.0  22-May-23  4th Qtr  0:01  False  804.0       5.0  False
#
#       lbscore  opscore opponent team  season  color
# ...

# %%
df=df.drop(columns=["team"])
df
# Out:
#         top   left       date      qtr  time result  shot  distance   lead  \
# 0     310.0  203.0  18-Oct-22  1st Qtr  9:26  False   3.0      26.0    NaN
# 1       NaN  259.0  18-Oct-22  1st Qtr  8:38  False   2.0      16.0  False
# 2     143.0    NaN  18-Oct-22  1st Qtr  8:10  False   2.0      11.0  False
# 3      68.0  215.0  18-Oct-22  1st Qtr   NaN    NaN   2.0       3.0    NaN
# 4      66.0  470.0  18-Oct-22  1st Qtr  1:02  False   NaN       NaN  False
# ...     ...    ...        ...      ...   ...    ...   ...       ...    ...
# 1528  118.0  274.0  22-May-23  4th Qtr  6:49  False   2.0       8.0  False
# 1529  109.0  221.0  22-May-23  4th Qtr  5:03  False   2.0       6.0  False
# 1530   78.0  254.0  22-May-23  4th Qtr  3:20    NaN   2.0       3.0  False
# 1531   78.0   46.0  22-May-23  4th Qtr  0:26  False   2.0       NaN  False
# 1532   58.0    NaN  22-May-23  4th Qtr  0:01  False   NaN       5.0  False
#
#       lbscore  opscore opponent  season  color
# ...

# %%
del df["shot"]
df
# Out:
#         top   left       date      qtr  time result  distance   lead  lbscore  \
# 0     310.0  203.0  18-Oct-22  1st Qtr  9:26  False      26.0    NaN      2.0
# 1       NaN  259.0  18-Oct-22  1st Qtr  8:38  False      16.0  False      NaN
# 2     143.0    NaN  18-Oct-22  1st Qtr  8:10  False      11.0  False      4.0
# 3      68.0  215.0  18-Oct-22  1st Qtr   NaN    NaN       3.0    NaN     12.0
# 4      66.0  470.0  18-Oct-22  1st Qtr  1:02  False       NaN  False     22.0
# ...     ...    ...        ...      ...   ...    ...       ...    ...      ...
# 1528  118.0  274.0  22-May-23  4th Qtr  6:49  False       8.0  False     98.0
# 1529  109.0  221.0  22-May-23  4th Qtr  5:03  False       6.0  False    100.0
# 1530   78.0  254.0  22-May-23  4th Qtr  3:20    NaN       3.0  False    104.0
# 1531   78.0   46.0  22-May-23  4th Qtr  0:26  False       NaN  False    111.0
# 1532   58.0    NaN  22-May-23  4th Qtr  0:01  False       5.0  False      NaN
#
# ...

# %%
df['left'].fillna('red')
df['left']
# Out:
# 0       203.0
# 1       259.0
# 2         NaN
# 3       215.0
# 4       470.0
#         ...
# 1528    274.0
# 1529    221.0
# 1530    254.0
# 1531     46.0
# 1532      NaN
# Name: left, Length: 1533, dtype: float64

# %%
df.drop(["top"],axis=1,inplace=True)
df
# Out:
#        left       date      qtr  time result  distance   lead  lbscore  \
# 0     203.0  18-Oct-22  1st Qtr  9:26  False      26.0    NaN      2.0
# 1     259.0  18-Oct-22  1st Qtr  8:38  False      16.0  False      NaN
# 2       NaN  18-Oct-22  1st Qtr  8:10  False      11.0  False      4.0
# 3     215.0  18-Oct-22  1st Qtr   NaN    NaN       3.0    NaN     12.0
# 4     470.0  18-Oct-22  1st Qtr  1:02  False       NaN  False     22.0
# ...     ...        ...      ...   ...    ...       ...    ...      ...
# 1528  274.0  22-May-23  4th Qtr  6:49  False       8.0  False     98.0
# 1529  221.0  22-May-23  4th Qtr  5:03  False       6.0  False    100.0
# 1530  254.0  22-May-23  4th Qtr  3:20    NaN       3.0  False    104.0
# 1531   46.0  22-May-23  4th Qtr  0:26  False       NaN  False    111.0
# 1532    NaN  22-May-23  4th Qtr  0:01  False       5.0  False      NaN
#
#       opscore opponent  season  color
# 0         2.0      GSW  2023.0    red
# ...

# %%
df["left_new"] = df["left"].fillna(df["left"].mean())
df
# Out:
#        left       date      qtr  time result  distance   lead  lbscore  \
# 0     203.0  18-Oct-22  1st Qtr  9:26  False      26.0    NaN      2.0
# 1     259.0  18-Oct-22  1st Qtr  8:38  False      16.0  False      NaN
# 2       NaN  18-Oct-22  1st Qtr  8:10  False      11.0  False      4.0
# 3     215.0  18-Oct-22  1st Qtr   NaN    NaN       3.0    NaN     12.0
# 4     470.0  18-Oct-22  1st Qtr  1:02  False       NaN  False     22.0
# ...     ...        ...      ...   ...    ...       ...    ...      ...
# 1528  274.0  22-May-23  4th Qtr  6:49  False       8.0  False     98.0
# 1529  221.0  22-May-23  4th Qtr  5:03  False       6.0  False    100.0
# 1530  254.0  22-May-23  4th Qtr  3:20    NaN       3.0  False    104.0
# 1531   46.0  22-May-23  4th Qtr  0:26  False       NaN  False    111.0
# 1532    NaN  22-May-23  4th Qtr  0:01  False       5.0  False      NaN
#
#       opscore opponent  season  color    left_new
# 0         2.0      GSW  2023.0    red  203.000000
# ...

# %% [markdown]
# ## _**DATA MANIPULATION**_

# %%
df.insert(5, "newcol", 804)
df
# Out:
#        left       date      qtr  time result  newcol  distance   lead  \
# 0     203.0  18-Oct-22  1st Qtr  9:26  False     804      26.0    NaN
# 1     259.0  18-Oct-22  1st Qtr  8:38  False     804      16.0  False
# 2       NaN  18-Oct-22  1st Qtr  8:10  False     804      11.0  False
# 3     215.0  18-Oct-22  1st Qtr   NaN    NaN     804       3.0    NaN
# 4     470.0  18-Oct-22  1st Qtr  1:02  False     804       NaN  False
# ...     ...        ...      ...   ...    ...     ...       ...    ...
# 1528  274.0  22-May-23  4th Qtr  6:49  False     804       8.0  False
# 1529  221.0  22-May-23  4th Qtr  5:03  False     804       6.0  False
# 1530  254.0  22-May-23  4th Qtr  3:20    NaN     804       3.0  False
# 1531   46.0  22-May-23  4th Qtr  0:26  False     804       NaN  False
# 1532    NaN  22-May-23  4th Qtr  0:01  False     804       5.0  False
#
#       lbscore  opscore opponent  season  color    left_new       col2
# ...

# %%
df['col2']=df["distance"].mean()
df['col2']
df
# Out:
#        left       date      qtr  time result  distance   lead  lbscore  \
# 0     203.0  18-Oct-22  1st Qtr  9:26  False      26.0    NaN      2.0
# 1     259.0  18-Oct-22  1st Qtr  8:38  False      16.0  False      NaN
# 2       NaN  18-Oct-22  1st Qtr  8:10  False      11.0  False      4.0
# 3     215.0  18-Oct-22  1st Qtr   NaN    NaN       3.0    NaN     12.0
# 4     470.0  18-Oct-22  1st Qtr  1:02  False       NaN  False     22.0
# ...     ...        ...      ...   ...    ...       ...    ...      ...
# 1528  274.0  22-May-23  4th Qtr  6:49  False       8.0  False     98.0
# 1529  221.0  22-May-23  4th Qtr  5:03  False       6.0  False    100.0
# 1530  254.0  22-May-23  4th Qtr  3:20    NaN       3.0  False    104.0
# 1531   46.0  22-May-23  4th Qtr  0:26  False       NaN  False    111.0
# 1532    NaN  22-May-23  4th Qtr  0:01  False       5.0  False      NaN
#
#       opscore opponent  season  color    left_new       col2
# ...

# %% [markdown]
# ## _**DATA DUPLICATIONS**_

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of        left       date      qtr  time result  shot  distance   lead  lbscore  \
# 0     203.0  18-Oct-22  1st Qtr  9:26  False   3.0      26.0    NaN      2.0
# 1     259.0  18-Oct-22  1st Qtr  8:38  False   2.0      16.0  False      NaN
# 2       NaN  18-Oct-22  1st Qtr  8:10  False   2.0      11.0  False      4.0
# 3     215.0  18-Oct-22  1st Qtr   NaN    NaN   2.0       3.0    NaN     12.0
# 4     470.0  18-Oct-22  1st Qtr  1:02  False   NaN       NaN  False     22.0
# ...     ...        ...      ...   ...    ...   ...       ...    ...      ...
# 1528  274.0  22-May-23  4th Qtr  6:49  False   2.0       8.0  False     98.0
# 1529  221.0  22-May-23  4th Qtr  5:03  False   2.0       6.0  False    100.0
# 1530  254.0  22-May-23  4th Qtr  3:20    NaN   2.0       3.0  False    104.0
# 1531   46.0  22-May-23  4th Qtr  0:26  False   2.0       NaN  False    111.0
# 1532    NaN  22-May-23  4th Qtr  0:01  False   NaN       5.0  False      NaN
#
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of        left       date      qtr  time result  shot  distance   lead  lbscore  \
# 0     203.0  18-Oct-22  1st Qtr  9:26  False   3.0      26.0    NaN      2.0
# 1     259.0  18-Oct-22  1st Qtr  8:38  False   2.0      16.0  False      NaN
# 2       NaN  18-Oct-22  1st Qtr  8:10  False   2.0      11.0  False      4.0
# 3     215.0  18-Oct-22  1st Qtr   NaN    NaN   2.0       3.0    NaN     12.0
# 4     470.0  18-Oct-22  1st Qtr  1:02  False   NaN       NaN  False     22.0
# ...     ...        ...      ...   ...    ...   ...       ...    ...      ...
# 1528  274.0  22-May-23  4th Qtr  6:49  False   2.0       8.0  False     98.0
# 1529  221.0  22-May-23  4th Qtr  5:03  False   2.0       6.0  False    100.0
# 1530  254.0  22-May-23  4th Qtr  3:20    NaN   2.0       3.0  False    104.0
# 1531   46.0  22-May-23  4th Qtr  0:26  False   2.0       NaN  False    111.0
# 1532    NaN  22-May-23  4th Qtr  0:01  False   NaN       5.0  False      NaN
#
# ...

# %% [markdown]
# ## _**CHANGE DATA TYPES**_

# %%
df['left'] = df['left'].astype(bool)
df.dtypes
# Out:
# top                    float64
# left                      bool
# date                    object
# qtr                     object
# time_remaining          object
# result                  object
# shot_type              float64
# distance_ft            float64
# lead                    object
# lebron_team_score      float64
# opponent_team_score    float64
# opponent                object
# team                    object
# season                 float64
# color                   object
# dtype: object

# %% [markdown]
# ## _**ADD NEW COLUMNS**_

# %%
df["new_col"]=df["left"].mean()
df
# Out:
#        left       date      qtr  time result  shot  distance   lead  lbscore  \
# 0     203.0  18-Oct-22  1st Qtr  9:26  False   3.0      26.0    NaN      2.0
# 1     259.0  18-Oct-22  1st Qtr  8:38  False   2.0      16.0  False      NaN
# 2       NaN  18-Oct-22  1st Qtr  8:10  False   2.0      11.0  False      4.0
# 3     215.0  18-Oct-22  1st Qtr   NaN    NaN   2.0       3.0    NaN     12.0
# 4     470.0  18-Oct-22  1st Qtr  1:02  False   NaN       NaN  False     22.0
# ...     ...        ...      ...   ...    ...   ...       ...    ...      ...
# 1528  274.0  22-May-23  4th Qtr  6:49  False   2.0       8.0  False     98.0
# 1529  221.0  22-May-23  4th Qtr  5:03  False   2.0       6.0  False    100.0
# 1530  254.0  22-May-23  4th Qtr  3:20    NaN   2.0       3.0  False    104.0
# 1531   46.0  22-May-23  4th Qtr  0:26  False   2.0       NaN  False    111.0
# 1532    NaN  22-May-23  4th Qtr  0:01  False   NaN       5.0  False      NaN
#
# ...

# %% [markdown]
# ## _**REMOVE A COLUMN**_

# %%
df.drop(columns=["new_col"], inplace=True)
df
# Out:
#        left       date      qtr  time result  shot  distance   lead  lbscore  \
# 0     203.0  18-Oct-22  1st Qtr  9:26  False   3.0      26.0    NaN      2.0
# 1     259.0  18-Oct-22  1st Qtr  8:38  False   2.0      16.0  False      NaN
# 2       NaN  18-Oct-22  1st Qtr  8:10  False   2.0      11.0  False      4.0
# 3     215.0  18-Oct-22  1st Qtr   NaN    NaN   2.0       3.0    NaN     12.0
# 4     470.0  18-Oct-22  1st Qtr  1:02  False   NaN       NaN  False     22.0
# ...     ...        ...      ...   ...    ...   ...       ...    ...      ...
# 1528  274.0  22-May-23  4th Qtr  6:49  False   2.0       8.0  False     98.0
# 1529  221.0  22-May-23  4th Qtr  5:03  False   2.0       6.0  False    100.0
# 1530  254.0  22-May-23  4th Qtr  3:20    NaN   2.0       3.0  False    104.0
# 1531   46.0  22-May-23  4th Qtr  0:26  False   2.0       NaN  False    111.0
# 1532    NaN  22-May-23  4th Qtr  0:01  False   NaN       5.0  False      NaN
#
#       opscore opponent team  season  color
# ...

# %% [markdown]
# ## _**ADD NEW ROW**_

# %%
a = pd.DataFrame({'date':804,
                  'left':804,
                    'color':'purpule'},
                     index=[0])
a
df=pd.concat([a,df])
df
# Out:
#            date   left    color    top      qtr  time result  shot  distance  \
# 0           804  804.0  purpule    NaN      NaN   NaN    NaN   NaN       NaN
# 0           NaN  804.0  purpule  804.0      NaN   NaN    NaN   NaN       NaN
# 0     18-Oct-22  203.0      red    NaN  1st Qtr  9:26  False   3.0      26.0
# 1     18-Oct-22  259.0      red    NaN  1st Qtr  8:38  False   2.0      16.0
# 2     18-Oct-22    NaN      red    NaN  1st Qtr  8:10  False   2.0      11.0
# ...         ...    ...      ...    ...      ...   ...    ...   ...       ...
# 1528  22-May-23  274.0      NaN    NaN  4th Qtr  6:49  False   2.0       8.0
# 1529  22-May-23  221.0      red    NaN  4th Qtr  5:03  False   2.0       6.0
# 1530  22-May-23  254.0    green    NaN  4th Qtr  3:20    NaN   2.0       3.0
# 1531  22-May-23   46.0      red    NaN  4th Qtr  0:26  False   2.0       NaN
# 1532  22-May-23    NaN      red    NaN  4th Qtr  0:01  False   NaN       5.0
#
# ...

# %% [markdown]
# ## _**REMOVE A ROW**_

# %%
df. drop(0,inplace=True)
df
# Out:
#            date   left  color  top      qtr   time result  shot  distance  \
# 1     18-Oct-22  259.0    red  NaN  1st Qtr   8:38  False   2.0      16.0
# 2     18-Oct-22    NaN    red  NaN  1st Qtr   8:10  False   2.0      11.0
# 3     18-Oct-22  215.0  green  NaN  1st Qtr    NaN    NaN   2.0       3.0
# 4     18-Oct-22  470.0    red  NaN  1st Qtr   1:02  False   NaN       NaN
# 5     18-Oct-22  239.0  green  NaN  2nd Qtr  11:30   True   2.0       1.0
# ...         ...    ...    ...  ...      ...    ...    ...   ...       ...
# 1528  22-May-23  274.0    NaN  NaN  4th Qtr   6:49  False   2.0       8.0
# 1529  22-May-23  221.0    red  NaN  4th Qtr   5:03  False   2.0       6.0
# 1530  22-May-23  254.0  green  NaN  4th Qtr   3:20    NaN   2.0       3.0
# 1531  22-May-23   46.0    red  NaN  4th Qtr   0:26  False   2.0       NaN
# 1532  22-May-23    NaN    red  NaN  4th Qtr   0:01  False   NaN       5.0
#
#        lead  lbscore  opscore opponent team  season
# ...

# %% [markdown]
# ## _**SPECIFIC DATA**_

# %%
df[4:6]
# Out:
#         date   left  color  top      qtr   time result  shot  distance   lead  \
# 5  18-Oct-22  239.0  green  NaN  2nd Qtr  11:30   True   2.0       1.0  False
# 6  18-Oct-22   54.0    red  NaN  2nd Qtr  10:30  False   3.0      26.0  False
#
#    lbscore  opscore opponent team  season
# 5     24.0     25.0      GSW  NaN  2023.0
# 6     24.0     27.0      GSW  LAL  2023.0

# %%
df[3:5:2]
# Out:
#         date   left color  top      qtr  time result  shot  distance   lead  \
# 4  18-Oct-22  470.0   red  NaN  1st Qtr  1:02  False   NaN       NaN  False
#
#    lbscore  opscore opponent team  season
# 4     22.0      NaN      GSW  LAL  2023.0

# %%
df[['left']][30:40]
# Out:
#      left
# 30  191.0
# 31  171.0
# 32  235.0
# 33  240.0
# 34  226.0
# 35  243.0
# 36  130.0
# 37  257.0
# 38   72.0
# 39  218.0

# %% [markdown]
# ## _**DATA AGGREGATION**_

# %%
df.agg({'left': ['sum', 'mean']})
# Out:
#                left
# sum   327869.000000
# mean     231.219323

# %%
df.groupby('left')

# %%
df["color"].value_counts()
# Out:
# color
# green    721
# red      715
# Name: count, dtype: int64

# %% [markdown]
# ## _**DATA FILTERING**_

# %%
df.describe(include="all").iloc[[0,10]]
# Out:
#        date    left color  top   qtr  time result    shot  distance  lead  \
# count  1437  1418.0  1436  0.0  1433  1440   1432  1423.0    1418.0  1431
# max     NaN   478.0   NaN  NaN   NaN   NaN    NaN     3.0      34.0   NaN
#
#        lbscore  opscore opponent  team  season
# count   1415.0   1432.0     1425  1421  1416.0
# max      140.0    133.0      NaN   NaN  2023.0

# %%
df.describe(include="all").loc[["min","max"]]
# Out:
#     date   left color  top  qtr time result  shot  distance lead  lbscore  \
# min  NaN    0.0   NaN  NaN  NaN  NaN    NaN   2.0       0.0  NaN      0.0
# max  NaN  478.0   NaN  NaN  NaN  NaN    NaN   3.0      34.0  NaN    140.0
#
#      opscore opponent team  season
# min      0.0      NaN  NaN  2023.0
# max    133.0      NaN  NaN  2023.0

# %% [markdown]
# ## _**FLOW CHARTS**_

# %%
df["color"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='color'>

# %%
df["color"].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["color"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["color"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='color'>

# %% [markdown]
# ## _**STATISTICAL ANALYSIS**_

# %%
df['left'].mean()
# Out:
# 231.6229739252995

# %%
df['left'].median()
# Out:
# 238.0

# %%
df['left'].mode()
# Out:
# 0    240.0
# Name: left, dtype: float64

# %%
df['left'].min()
# Out:
# 0.0

# %%
df['left'].max()
# Out:
# 804.0

# %%
df['left'].std()
# Out:
# 93.00331102228144

# %% [markdown]
# ## _**SAVE DATA**_

# %%
df=pd.read_csv("pf.csv")
df
df.to_excel("new_project.xlsx", sheet_name="secsheet")
